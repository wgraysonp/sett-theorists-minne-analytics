# %%
import pandas as pd
import seaborn as sns
import sklearn as sk
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('../data/Training.xlsx')

# %%
df.head()
# Out:
#       Match ID 18Char Completion Date  \
# 0  a1v2J0000028pRvQAI      2017-11-30
# 1  a1v2J0000028pRvQAI      2017-10-31
# 2  a1v2J0000028pRvQAI      2017-12-01
# 3  a1v2J0000028pRvQAI      2017-05-29
# 4  a1v2J0000028pRvQAI      2017-04-30
#
#                          Match Support Contact Notes   Stage  \
# 0  Question: Activities:           Answer: See ms...  Closed
# 1  Question: Activities:           Answer: See MS...  Closed
# 2  Question: Activities:           Answer: Match ...  Closed
# 3  Question: Activities:           Answer: Msc as...  Closed
# 4  Question: Activities:           Answer: Msc as...  Closed
#
#             Little ID           Big ID Big County  Big Age Big Occupation  \
# 0  0032J00003PLe29QAD  0032J00003PhDOI   Hennepin       40     Unemployed
# 1  0032J00003PLe29QAD  0032J00003PhDOI   Hennepin       40     Unemployed
# 2  0032J00003PLe29QAD  0032J00003PhDOI   Hennepin       40     Unemployed
# ...

# %%
df.describe()
# Out:
#                      Completion Date       Big Age  \
# count                          39198  39345.000000
# mean   2020-12-09 07:07:50.044390144     36.378828
# min              2017-01-11 00:00:00     19.000000
# 25%              2018-12-31 06:00:00     29.000000
# 50%              2020-09-23 00:00:00     33.000000
# 75%              2022-10-14 00:00:00     40.000000
# max              2025-02-24 00:00:00     80.000000
# std                              NaN     10.996065
#
#                    Big Approved Date                  Big Birthdate  \
# count                          35277                          39345
# mean   2020-01-18 04:54:57.831448320  1988-03-25 22:42:42.134959936
# min              2017-05-01 00:00:00            1944-04-01 00:00:00
# 25%              2018-05-09 00:00:00            1984-08-01 00:00:00
# 50%              2019-08-16 00:00:00            1991-05-01 00:00:00
# 75%              2021-06-29 00:00:00            1995-07-01 00:00:00
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39345 entries, 0 to 39344
# Data columns (total 68 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   Match ID 18Char                                    39345 non-null  object
#  1   Completion Date                                    39198 non-null  datetime64[ns]
#  2   Match Support Contact Notes                        37891 non-null  object
#  3   Stage                                              39345 non-null  object
#  4   Little ID                                          39345 non-null  object
#  5   Big ID                                             39345 non-null  object
#  6   Big County                                         32357 non-null  object
#  7   Big Age                                            39345 non-null  int64
# ...

# %%
sns.displot(df, x='Match Length')
